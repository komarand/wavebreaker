# %%
params = {"n_estimators": 3000, "learning_rate": 0.02, "num_leaves": 64}

# %%
model = LGBMClassifier(**params)

# %%
xgb = XGBClassifier(**params, n_estimators=500)

# %%
cat = CatBoostClassifier(**unknown_name)
