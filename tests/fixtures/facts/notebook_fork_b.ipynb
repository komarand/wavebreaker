# %% [markdown]
# # Tuned fork B with different constants

# %%
# Changed seed and hyperparameters after tuning
SEED = 2026
splitter = StratifiedKFold(n_splits=10, shuffle=True, random_state=2026)
model = LGBMClassifier(n_estimators=1200, learning_rate=0.01, max_depth=12)
