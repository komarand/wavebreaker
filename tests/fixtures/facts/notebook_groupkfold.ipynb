# %% [markdown]
# # Validation
# CV 0.7841

# %%
from sklearn.model_selection import StratifiedGroupKFold
from lightgbm import LGBMClassifier

splitter = StratifiedGroupKFold(n_splits=5, shuffle=True, groups=customer_id)
model = LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=31)

# %%
score = roc_auc_score(y_true, predictions)
features = frame.groupby(customer_id).agg({'amount': 'mean'})
