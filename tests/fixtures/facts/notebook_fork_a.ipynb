# %% [markdown]
# # Baseline fork A

# %%
# Original baseline settings
SEED = 42
splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
model = LGBMClassifier(n_estimators=500, learning_rate=0.05, max_depth=7)
